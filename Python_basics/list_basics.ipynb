# %%
my_list=[80,96,72,100,8]
print (my_list)
"""
lists are ordered , once you add elements order wont change
they are mutable -you can change any element any time
it allows duplicate elements
They can store different dat types in the same list
they can grow or shrink at run time
supports indexing and slicing - access elements using index and slice ranges.
They are iterable
backed by dynamic array behind the scenes
"""

people_list =['Eric','Adil','Jeff']
people_list[0] ='Ml'
people_list.insert(2,'Satish')
people_list.remove('Adil')
print(people_list)

# %%
zoo =['Elephant','Tiger','Lion','Ziraffe','Zebra']
print (zoo)
zoo.append('Snake')
zoo.remove(zoo[3])
print(zoo)


print(zoo[0:3])
# Out:
# ['Elephant', 'Tiger', 'Lion', 'Ziraffe', 'Zebra']
# ['Elephant', 'Tiger', 'Lion', 'Zebra', 'Snake']
# ['Elephant', 'Tiger', 'Lion']
