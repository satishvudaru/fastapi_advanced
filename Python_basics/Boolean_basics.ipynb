# %%
x=2
if(x==1):
    print('x =1 ')
else :
    print('x is not greater than 1')
# Out:
# x is not greater than 1

# %%
grade = 50

if(grade >=90):
    print ('A')
elif (grade >=80 and grade <=90):
    print('B')
if (grade >=70 and grade <=79):
    print('C')

# %%
#Loops in python

my_list =[1,2,3,4,5]
sum_oflistelements =0
for i in range(len(my_list)):
    print(my_list[i])
    sum_oflistelements += my_list[i]

print(sum_oflistelements)
# Out:
# 1
# 2
# 3
# 4
# 5
# 15

# %%
my_list = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]

i =3
while i>0:
    for x in my_list:
        if(x=='Monday'):
            continue
        else:
            print(x)
        
    i-=1

# %%
"""
Recap 

Creating a list   my+list =[1,2,3 ] 
they are mutable, can be indexed and sliced , maintains order , they are mutable

Creating a set  - 2 ways

a =set() -creates empty set

a ={1,2,3}
a={} -- creates a dictionary. they contains unique values, they cannot be accessed through index, they are immutable

tuple 
a = (1,2,3) they can be indexed, sliced, they are immutable at element level they use hash to store values
"""

# %%
user_dictionary = {'username':'codingwithsatish',
'name':'Eric',
'age':32
}
 
user_dictionary['Gender']='Male'
print(user_dictionary)


#remove element from dictionary

user_dictionary.pop('Gender')
print(user_dictionary)

#Print keys and values from dictionary
for x,y in user_dictionary.items():
    print(f'Key:{x}, Value: {y}')
# Out:
# {'username': 'codingwithsatish', 'name': 'Eric', 'age': 32, 'Gender': 'Male'}
# {'username': 'codingwithsatish', 'name': 'Eric', 'age': 32}
# Key:username, Value: codingwithsatish
# Key:name, Value: Eric
# Key:age, Value: 32

# %%
#Assignment on dictioanry

my_vehicle ={'model':'Ford',
'make':'Explorer',
'year':2018,
'mileage':4000}

for x in my_vehicle:
    print(f'Key is {x},value is : {my_vehicle.get(x)}')

vehicle2 = my_vehicle

vehicle2['number_of_tires']=4
print(vehicle2)
#delete a key form dictionary
vehicle2.pop('mileage')
print(vehicle2)

for x,y in vehicle2.items():
    print(f'Key is {x}  Value is {y}')
# Out:
# Key is model,value is : Ford
# Key is make,value is : Explorer
# Key is year,value is : 2018
# Key is mileage,value is : 4000
# {'model': 'Ford', 'make': 'Explorer', 'year': 2018, 'mileage': 4000, 'number_of_tires': 4}
# {'model': 'Ford', 'make': 'Explorer', 'year': 2018, 'number_of_tires': 4}
# Key is model  Value is Ford
# Key is make  Value is Explorer
# Key is year  Value is 2018
# Key is number_of_tires  Value is 4
